# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
dfa=pd.read_csv('ToyotaCorolla.csv')
dfa
# Out:
#         Id  Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  \
# 0        1  13500         23         10      2002  46986    Diesel   90
# 1        2  13750         23         10      2002  72937    Diesel   90
# 2        3  13950         24          9      2002  41711    Diesel   90
# 3        4  14950         26          7      2002  48000    Diesel   90
# 4        5  13750         30          3      2002  38500    Diesel   90
# ...    ...    ...        ...        ...       ...    ...       ...  ...
# 1431  1438   7500         69         12      1998  20544    Petrol   86
# 1432  1439  10845         72          9      1998  19000    Petrol   86
# 1433  1440   8500         71         10      1998  17016    Petrol   86
# 1434  1441   7250         70         11      1998  16916    Petrol   86
# 1435  1442   6950         76          5      1998      1    Petrol  110
#
#       Met_Color   Color  ...  Central_Lock  Powered_Windows  Power_Steering  \
# ...

# %%
dfa.drop(columns=['Id'])
# Out:
#       Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  \
# 0     13500         23         10      2002  46986    Diesel   90          1
# 1     13750         23         10      2002  72937    Diesel   90          1
# 2     13950         24          9      2002  41711    Diesel   90          1
# 3     14950         26          7      2002  48000    Diesel   90          0
# 4     13750         30          3      2002  38500    Diesel   90          0
# ...     ...        ...        ...       ...    ...       ...  ...        ...
# 1431   7500         69         12      1998  20544    Petrol   86          1
# 1432  10845         72          9      1998  19000    Petrol   86          0
# 1433   8500         71         10      1998  17016    Petrol   86          0
# 1434   7250         70         11      1998  16916    Petrol   86          1
# 1435   6950         76          5      1998      1    Petrol  110          0
#
# ...

# %% [markdown]
# # EDA

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Price             1436 non-null   int64
#  2   Age_08_04         1436 non-null   int64
#  3   Mfg_Month         1436 non-null   int64
#  4   Mfg_Year          1436 non-null   int64
#  5   KM                1436 non-null   int64
#  6   Fuel_Type         1436 non-null   object
#  7   HP                1436 non-null   int64
#  8   Met_Color         1436 non-null   int64
#  9   Color             1436 non-null   object
#  10  Automatic         1436 non-null   int64
#  11  cc                1436 non-null   int64
#  12  Doors             1436 non-null   int64
#  13  Cylinders         1436 non-null   int64
#  14  Gears             1436 non-null   int64
#  15  Quarterly_Tax     1436 non-null   int64
# ...

# %%
df=dfa[["Price","Age_08_04","KM","HP","cc","Doors","Quarterly_Tax","Weight"]]
df
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3            210    1165
# 1     13750         23  72937   90  2000      3            210    1165
# 2     13950         24  41711   90  2000      3            210    1165
# 3     14950         26  48000   90  2000      3            210    1165
# 4     13750         30  38500   90  2000      3            210    1170
# ...     ...        ...    ...  ...   ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3             69    1025
# 1432  10845         72  19000   86  1300      3             69    1015
# 1433   8500         71  17016   86  1300      3             69    1015
# 1434   7250         70  16916   86  1300      3             69    1015
# 1435   6950         76      1  110  1600      5             19    1114
#
# [1436 rows x 8 columns]

# %%
df=df.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
df
# Out:
#       Price  Age     KM   HP    CC  Doors   QT  Weight
# 0     13500   23  46986   90  2000      3  210    1165
# 1     13750   23  72937   90  2000      3  210    1165
# 2     13950   24  41711   90  2000      3  210    1165
# 3     14950   26  48000   90  2000      3  210    1165
# 4     13750   30  38500   90  2000      3  210    1170
# ...     ...  ...    ...  ...   ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3   69    1025
# 1432  10845   72  19000   86  1300      3   69    1015
# 1433   8500   71  17016   86  1300      3   69    1015
# 1434   7250   70  16916   86  1300      3   69    1015
# 1435   6950   76      1  110  1600      5   19    1114
#
# [1436 rows x 8 columns]

# %%
df.describe()
# Out:
#               Price          Age             KM           HP           CC  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors           QT      Weight
# count  1436.000000  1436.000000  1436.00000
# mean      4.033426    87.122563  1072.45961
# std       0.952677    41.128611    52.64112
# min       2.000000    19.000000  1000.00000
# 25%       3.000000    69.000000  1040.00000
# ...

# %%
df.isna().sum()
# Out:
# Price     0
# Age       0
# KM        0
# HP        0
# CC        0
# Doors     0
# QT        0
# Weight    0
# dtype: int64

# %%
df.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors        QT  \
# Price   1.000000 -0.876590 -0.569960  0.314990  0.126389  0.185326  0.219197
# Age    -0.876590  1.000000  0.505672 -0.156622 -0.098084 -0.148359 -0.198431
# KM     -0.569960  0.505672  1.000000 -0.333538  0.102683 -0.036197  0.278165
# HP      0.314990 -0.156622 -0.333538  1.000000  0.035856  0.092424 -0.298432
# CC      0.126389 -0.098084  0.102683  0.035856  1.000000  0.079903  0.306996
# Doors   0.185326 -0.148359 -0.036197  0.092424  0.079903  1.000000  0.109363
# QT      0.219197 -0.198431  0.278165 -0.298432  0.306996  0.109363  1.000000
# Weight  0.581198 -0.470253 -0.028598  0.089614  0.335637  0.302618  0.626134
#
#           Weight
# Price   0.581198
# Age    -0.470253
# KM     -0.028598
# HP      0.089614
# CC      0.335637
# Doors   0.302618
# QT      0.626134
# Weight  1.000000

# %%
# check multi-colinarity

# %%
pd.plotting.scatter_matrix
sns.pairplot(df)

# %%
#  model building

model=smf.ols('Price~Age+KM+HP+CC+Doors+QT+Weight',data=df).fit()
model

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1284.
# Date:                Wed, 08 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:39:59   Log-Likelihood:                -12380.
# No. Observations:                1436   AIC:                         2.478e+04
# Df Residuals:                    1428   BIC:                         2.482e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2750.5553   1059.491     -2.596      0.010   -4828.881    -672.229
# ...

# %% [markdown]
# # calculating VIF

# %%
v_age=smf.ols('Age~KM+HP+CC+Doors+QT+Weight',data=df).fit().rsquared
vif_age=1/(1-v_age)

v_km=smf.ols('KM~Age+HP+CC+Doors+QT+Weight',data=df).fit().rsquared
vif_km=1/(1-v_age)

v_hp=smf.ols('HP~Age+KM+CC+Doors+QT+Weight',data=df).fit().rsquared
vif_hp=1/(1-v_age)

v_cc=smf.ols('CC~Age+KM+HP+Doors+QT+Weight',data=df).fit().rsquared
vif_cc=1/(1-v_age)

v_Doors=smf.ols('Doors~Age+KM+HP+CC+QT+Weight',data=df).fit().rsquared
vif_Doors=1/(1-v_age)

v_QT=smf.ols('QT~Age+KM+HP+CC+Doors+Weight',data=df).fit().rsquared
vif_QT=1/(1-v_age)

v_weight=smf.ols('Weight~QT+Age+KM+HP+CC+Doors',data=df).fit().rsquared
vif_weight=1/(1-v_age)

# %%
vif=pd.DataFrame({
    'Features' : ['Age','KM','HP','CC','Doors','QT','Weight'],
    'vif'      : [vif_age,vif_km,vif_hp,vif_cc,vif_Doors,vif_QT,vif_weight]
})
vif
# Out:
#   Features       vif
# 0      Age  1.884073
# 1       KM  1.884073
# 2       HP  1.884073
# 3       CC  1.884073
# 4    Doors  1.884073
# 5       QT  1.884073
# 6   Weight  1.884073

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') 
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))
# Out:
# [array([147, 523], dtype=int64)]

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (80, 91.60492711468393)

# %%
df1=df.drop(df.index[[80]],axis=0)

# %%
df1.head()
# Out:
#    Price  Age     KM  HP    CC  Doors   QT  Weight
# 0  13500   23  46986  90  2000      3  210    1165
# 1  13750   23  72937  90  2000      3  210    1165
# 2  13950   24  41711  90  2000      3  210    1165
# 3  14950   26  48000  90  2000      3  210    1165
# 4  13750   30  38500  90  2000      3  210    1170

# %%
#Reset the index and re arrange the row values
df2=df1.reset_index()

# %%
final_model=smf.ols('Price~Age+KM+HP+CC+Doors+QT+Weight',data=df2).fit()
final_model

# %%
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     1349.
# Date:                Wed, 08 Feb 2023   Prob (F-statistic):               0.00
# Time:                        21:40:01   Log-Likelihood:                -12338.
# No. Observations:                1435   AIC:                         2.469e+04
# Df Residuals:                    1427   BIC:                         2.473e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3811.9846   1043.223     -3.654      0.000   -5858.400   -1765.569
# ...

# %% [markdown]
# # Predicting for new data

# %%
newdata=pd.DataFrame({
    'Age':[30],
    'KM' :[25001],
    'HP' :[101],
    'CC' :[2500],
    'Doors':[3],
    'QT' :[90],
    'Weight':[1200]
})
final_model.predict(newdata)
# Out:
# 0    14866.461023
# dtype: float64
